# %% [markdown]
# <a href="https://colab.research.google.com/github/sidra3921/stock-price-forecasting-sidra2225165138/blob/main/Week3_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 📅 Week 3 – Data Visualization
# Name: Sidra
# Project: Stock Price Forecasting (Apple Dataset)
# Course: Applied Data Science with AI

# %%
# !mkdir -p data/raw

# %%
# !unzip 10-year-daily-stock-data-of-apple-2015-to-2025.zip -d data/raw
# Out:
# Archive:  10-year-daily-stock-data-of-apple-2015-to-2025.zip
#   inflating: data/raw/apple_stock_10years_daywise.xlsx

# %%
# !ls data/raw
# Out:
# apple_stock_10years_daywise.xlsx

# %%
import pandas as pd

df = pd.read_excel('data/raw/apple_stock_10years_daywise.xlsx')
df['Date'] = pd.to_datetime(df['Date'])  # Date ko datetime format me convert karna

df.head()
# Out:
#         Date  Close   High    Low   Open     Volume
# 0 2015-04-13  28.33  28.71  28.28  28.67  145460400
# 1 2015-04-14  28.21  28.43  28.12  28.36  102098400
# 2 2015-04-15  28.31  28.39  28.14  28.23  115881600
# 3 2015-04-16  28.18  28.38  28.16  28.20  113476000
# 4 2015-04-17  27.86  28.17  27.80  28.04  207828000

# %%
import pandas as pd

# Excel file ko read karna
df = pd.read_excel('/content/data/raw/apple_stock_10years_daywise.xlsx')

# Date ko datetime me convert karna
df['Date'] = pd.to_datetime(df['Date'])

# First few rows dekhna
df.head()
# Out:
#         Date  Close   High    Low   Open     Volume
# 0 2015-04-13  28.33  28.71  28.28  28.67  145460400
# 1 2015-04-14  28.21  28.43  28.12  28.36  102098400
# 2 2015-04-15  28.31  28.39  28.14  28.23  115881600
# 3 2015-04-16  28.18  28.38  28.16  28.20  113476000
# 4 2015-04-17  27.86  28.17  27.80  28.04  207828000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Optional styling
plt.style.use('seaborn-v0_8')
sns.set_theme()

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Date'], df['Close'], color='blue')
plt.title('Apple Stock Closing Price (2015–2025)')
plt.xlabel('Year')
plt.ylabel('Closing Price (USD)')
plt.grid(True)
plt.show()

# %% [markdown]
# Insight:
# The line plot clearly shows a strong upward trend in Apple’s stock price over the years. After 2020, the price increased significantly, indicating accelerated market growth and investor confidence. There are also small dips that reflect short-term market fluctuations.

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Close'], bins=30, color='green', edgecolor='black')
plt.title('Distribution of Closing Price')
plt.xlabel('Closing Price (USD)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Insight:
# The histogram reveals that most of the closing prices are concentrated between $50 and $150. This indicates that for a large portion of the decade, Apple’s stock price remained in this stable range before rising sharply in later years.

# %%
plt.figure(figsize=(6,5))
sns.boxplot(y=df['High'], color='orange')
plt.title('Box Plot of High Prices')
plt.ylabel('Price (USD)')
plt.show()

# %% [markdown]
# Insight:
# The box plot highlights several outliers in the high price data. These outliers represent days when Apple’s stock price experienced unusual spikes, likely due to major product launches, market announcements, or broader economic events.

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['Open'], df['Close'], alpha=0.5, color='purple')
plt.title('Open Price vs Close Price')
plt.xlabel('Open Price')
plt.ylabel('Close Price')
plt.show()

# %% [markdown]
# Insight:
# The scatter plot shows a clear positive correlation between opening and closing prices. When the opening price is high, the closing price also tends to be high. This indicates consistent daily trading behavior and stable market performance for Apple stock.

# %%
df['Year'] = df['Date'].dt.year
yearly_avg = df.groupby('Year')['Close'].mean()

plt.figure(figsize=(12,6))
yearly_avg.plot(kind='bar', color='teal')
plt.title('Average Closing Price Per Year')
plt.xlabel('Year')
plt.ylabel('Average Close Price (USD)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Insight:
# The bar plot demonstrates a steady increase in the average closing price year over year. This upward trend is particularly sharp after 2020, reflecting Apple’s strong financial performance, increased investor trust, and market dominance.
